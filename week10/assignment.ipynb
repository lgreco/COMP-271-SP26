# %% [markdown]
# # Assignment 10: Hashing and Math Assessment

# %% [markdown]
# This assignment has two parts: a coding part and a math assessment. The coding part will involve implementing a hash table, while the math assessment will test your understanding of asymptotic analysis and related concepts.
# * Part A: up to 15 points (based on the correctness and quality of your implementation.)
# * Part B: 5 points (you'll earn these points by completing the math assessment, regardless of the correctness of your answers.)
#
# **Specifications and requirements.**  Each assignment must be compliant with the [Programmer's Pact](../housekeeping/ProgrammerPact_Python_2026.pdf).
#
#
#
# - You may **not** import any modules **except** for those already included in the codebase of the assignment or listed below:
#   - `from __future__ import annotations`
# - No sets or dictionaries may be used.
# - If your work requires additional methods to support the development of the methods the assignment asks for, you may write them.

# %% [markdown]
# ### Part A - A very simple hash operation
#
# Create a class `NameBins` whose underlying data structure is a `list[list[str]]`. The class should be initialized with a positive integer `n` that determines the number of bins.
#
# Each bin is a list within the underlying data structure. From example if `n=3` then the underlying data structure is `[[], [], []]`. The class should have a method `add_name(name: str)` that adds a name to the appropriate bin, according to the initial letter of the name.
#
# Each bin is assigned a range of letters. For example, if `n=3` then the first bin is for names that start with letters `A` through `I`, the second bin is for names that start with letters `J` through `R`, and the third bin is for names that start with letters `S` through `Z`.
#
# Assume that all names are in the english alphabet and that they are capitalized. You do not need to worry about names that start with non-alphabetic characters or lowercase letters.
#
# If `n` does not divide the alphabet evenly, then the last bin will have more letters than the others. For example, if `n=4` then the first three bins will be for names that start with letters `A` through `G`, `H` through `N`, and `O` through `U`, and the fourth bin will be for names that start with letters `V` through `Z`.
#
# Sounds simple enough, but **there is a catch:** you are **not allowed** to use the `if` statement or any other conditional statements (like `match`, `try/except`, etc.) in your implementation of the `add_name` method. You can may use conditional statements to determine the ranges of letters for each bin.  (Hint: use integer division, not modulo `%` for this problem).
#
# Class `NameBins` should have the following methods:
#
# * `__init__(self, n: int) -> None`
# * `add_name(self, name: str) -> None`
# * `__str__(self) -> str` to return a *nicely formatted* string representation of the underlying data structure
# * `size(self) -> int` to return the total number of names in all bins

# %% [markdown]
# ### Part B - Math assessment
#
# This part will not impact your course grade. **You will receive credit for completing it, regardless of the correctness of your answers.** The purpose of this part is to give your instructors an idea of your current understanding of the mathematical concepts that are relevant to the course, and to identify areas where you may need additional support. It is important that you attempt to answer all questions to the best of your ability, as this will help us tailor our instruction to better meet your needs. You may use any resources you like to answer the questions, including textbooks, online resources, and discussions with classmates. However, we encourage you to try to understand the concepts on your own before seeking help, as this will enhance your learning experience.
#
# #### Question 1: Concepts of asymptotic behavior
#
# In computer science, we often analyze the [asymptotic behavior](./asymptotic.ipynb) of our data structures and algorithms.
#    * What does the asymptotic behavior of a function mean in the context of computer science? (2-3 lines)
#    * Explain briefly why algorithm analysis focuses on asymptotic behavior rather than exact running times. (1-2 lines)
#
# #### Question 2: Limits and asymptotic interpretation
#
# Mathematically, asymptotic behavior is closely related to limit notation, which studies how functions behave as the input size grows very large.
#
# **2.1 Meaning of limit notation**
#
# Explain the meaning of the notation
# $$\lim_{n \to \infty} {f(n)}$$
# What does this notation describe about the behavior of the function $f(n)$? (1-2 lines)
#
# **2.2 Compute limits**
#
# Calculate the following limits, showing your work:
# $$
# \begin{align*}
# \textsf{a.} & \quad \lim_{n \to \infty} 7 \\ \\
# \textsf{b.} & \quad \lim_{n \to \infty} n \\ \\
# \textsf{c.} & \quad \lim_{n \to \infty} \frac{1}{n} \\ \\
# \textsf{d.} & \quad \lim_{n \to \infty} \frac{3n+5}{n} \\ \\
# \textsf{e.} & \quad \lim_{n \to \infty} \frac{3n+5}{n^2}
# \end{align*}
# $$
#
# **2.3 Asymptotic relationships and limits**
#
# Let $f(n)$ and $g(n)$ be two functions. In asymptoic analysis, we often write $g(n)=\mathcal O(f(n))$ to indicate that $g(n)$ grows at most as fast as $f(n)$ up to a constant factor. This means that for sufficiently large n, the growth of $g(n)$ is bounded above by a constant multiple of $f(n)$. Explain how this relationship can be expressed using limit notation involving as $n \rightarrow \infty$. (Hint: consider the limit of the ratio of $g(n)$ to $f(n)$ as $n$ approaches infinity). (2-3 lines)
#
# #### Question 3:  Comparing and Combining Asymptotic Behaviors
#
#
# **Ordering functions by growth rate**
#
# Order the following functions from slowest growing to fastest growing as $n$ approaches infinity.
# $$
# \begin{align*}
# \textsf{A.} & \quad 2^n \\
# \textsf{B.} & \quad n^{1/2} \\
# \textsf{C.} & \quad n^2 \\
# \textsf{D.} & \quad n \log n \\
# \textsf{E.} & \quad n \\
# \textsf{F.} & \quad \log n
# \end{align*}
# $$
#
# **Determine asymptotic behavior**
#
# Consider the following two functions:
# $$
# \begin{align*}
# f(n) &= 5n^3 + n^2 + \log n + 50 \\
# g(n) &= n \log n + 100n
# \end{align*}
# $$
# Give the $\mathcal O$-notation for the asymptotic behavior of
# * $f(n)$
# * $g(n)$
# * $f(n)+g(n)$, and
# * $f(n)g(n)$
#
# and explain your reasoning.
#
#
# #### Question 4: Asymptotic running time of functions
#
# Determine the asymptotic running time (Big-Oh $\mathcal{O}$) of each function below. Briefly justify
# your answer for each function.
#
# ```python
# def func1(n):
#    if n % 2 == 0:
#       for i in range(n):
#       print(i)
#    else:
#       print("Hello")
#
# def func2(n):
#    count = 0
#    for i in range(n):
#       count += 1
#
# def func3(n):
#    if n > 1000:
#       for i in range(n):
#          print(i)
#    else:
#       for i in range(n):
#          for j in range(n):
#             print(i, j)
#
# def func4(n):
#    count = 0
#    for i in range(n):
#       for j in range(i):
#          count += 1
# ```
#
# Hint for `func4`: $1+2+\cdots+n = \dfrac{n(n+1)}{2}$.

# %% [markdown]
# ## What to submit
#
# A file called `week10.py` with you code, uploaded on Sakai. If your work is done in a Jupyter Notebook, make the notebook shareable and provide its link as the sole line of your `week10.py` file.
#
# A file called `math10.*` (with * meaning any of the following extensions: `.txt`, `.pdf`, `.docx`, etc.) with your answers to the math assessment, uploaded on Sakai. If your work is done in a Jupyter Notebook, make the notebook shareable and provide its link as the sole line of your `math10.txt*` file (note the txt extension in the name of the file in this case). You may also write your answers by hand using a tablet or on paper. In the case of tablet app, export your work as a PDF or PNG file and upload it on Sakai. In case of paper, take a **clear picture** of your work and upload it on Sakai as a PNG file. Low resolution pictures, photos with poor lighting, photos that are blurry, or photos where the work is not fully visible will not receive credit.

# %% [markdown]
# ## Reading
#
# - [Leo's brief note on asymptotic behavior](./asymptotic.ipynb)
# - [Asymptotic Analysis and Upper Bounds](https://opendsa-server.cs.vt.edu/OpenDSA/Books/Everything/html/AnalAsymptotic.html) from the OpenDSA book, free to read online.
