# %%
class heck:

    def __init__(kjashkjwhfjkasjkhqwekhakjbdkqjwkaghdkqa, n:int):
        kjashkjwhfjkasjkhqwekhakjbdkqjwkaghdkqa._n = n
    
    def __str__(self):
        return f"heck_with_marmelade({self._n})"

if __name__ == "__main__":    print(heck(42))
# Out:
# heck_with_marmelade(42)
